# %%
User_input=int(input("Enter a number: "))

binary_num_list=[]

def decimal_to_binary(decimal):
        
    while(decimal > 0):
        
        rem = decimal % 2
        
        binary_num_list.append(rem)
        
        decimal = decimal // 2
        
    binary_num_list.reverse()
    
    print("Binary Equivalent is: ")
    
    for i in binary_num_list:
        
        print(i, end=" ")
        
#     return bin_list

        
# def palindrome_checker(binary_list):
    
#     if User_input % 2 != 0 and binary_list == binary_list[::-1] :
        
#         print("\nThis word is a palindrome")
    
#     else:
        
#         print("\nThis word is not a palindrome")
        

# palindrome_checker(decimal_to_binary(User_input))
decimal_to_binary(User_input)

# %%
User_input=int(input("Enter a number: "))
# binss=[]

print("Binary Equivalent is: ")

def decimal_to_binary_rec(decimal):        # Recursive Function to convert decimal to binary
    
    if decimal > 1:
        
        decimal_to_binary(decimal // 2)        # recursive function call
        
    print(decimal % 2,end = " ")        # printing remainder from each function call
    
#     binss.append(decimal % 2)
    
#     return binss

# def palindrome_checker(binary_list):
    
#     if User_input % 2 != 0 and binary_list == binary_list[::-1] :
        
#         print("\nThis word is a palindrome")
    
#     else:
        
#         print("\nThis word is not a palindrome")
    
# palindrome_checker(decimal_to_binary(User_input))

decimal_to_binary_rec(User_input)
